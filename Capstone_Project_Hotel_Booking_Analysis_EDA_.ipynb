# %% [markdown]
# <a href="https://colab.research.google.com/github/MAYANKPRAJAPATI5/Hotel_Booking_Analysis_EDA_Capstone_project/blob/main/Capstone_Project_Hotel_Booking_Analysis_EDA_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -**Hotel Booking Analysis**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The given dataset is of hotel booking. I explored and analyzed the given dataset and discovered some important factors regarding hotel booking. For this, I first read the given data in my collab notebook and then understand the whole data like what are variables in the given data. After that cleaned the data frame in data wrangling. For that I used some functions like drop(), fillna(), isna()/isnull() functions. Then I added that columns which are required in
# the analysis and removed some columns which are not required. Using this data
# frame I explored some variables using visualization charts like pie charts, count plots, barplot,heatmaps and pairplot and I can find out some insights which are important factors. From these insights, I can suggest some business objectives to clients.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/MAYANKPRAJAPATI5/Hotel_Booking_Analysis_EDA_Capstone_project/tree/main

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**
# In this project we are going to analyse Hotel Booking dataset. This dataset contains information of city hotel and resort hotel, and includes information of booking time, length of stay, number of adults, children and/or babies.
#
# The objective of this project is explore and analyse the data to discover important factors regarding Hotels booking and its attributes.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Analyse the data on Hotel Booking and discover the different factors which affects the booking.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
# Importing libraries
import numpy as np
import pandas as pd
from numpy import math
from numpy import loadtxt
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rcParams

# %% [markdown]
# ### Dataset Loading

# %%
# My drive is mounted here.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load Dataset
Hotelbooking_dataset = '/content/drive/MyDrive/almabetter/Hotel Bookings.csv'
df = pd.read_csv(Hotelbooking_dataset)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head(5)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.tail(5)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
#Creating the copy of the dataset
df1 = df.copy()
df1.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
# Checking for Number of duplicate rows
duplicate_Rows = df1[df1.duplicated()].shape
print("No. of duplicate Entries",duplicate_Rows[0])

## Dropping duplicates
df1.drop_duplicates(inplace=True)
duplicate_Rows = df1[df1.duplicated()].shape
print("No. of duplicate Entries after removing are", duplicate_Rows[0])
# Out:
# No. of duplicate Entries 31994
# No. of duplicate Entries after removing are 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
null_value = df1.isnull() == True
df1.fillna(np.nan, inplace = True)

df1   # we replace all the null value as NaN.
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
# Visualizing the missing values(As we can see above only 4 columns have missing values)
missing_values=df1.isnull().sum().sort_values(ascending=False)

missing_values
# Out:
# company                           82137
# agent                             12193
# country                             452
# children                              4
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# hotel                                 0
# previous_cancellations                0
# days_in_waiting_list                  0
# customer_type                         0
# adr                                   0
# required_car_parking_spaces           0
# total_of_special_requests             0
# reservation_status                    0
# previous_bookings_not_canceled        0
# is_repeated_guest                     0
# is_canceled                           0
# distribution_channel                  0
# market_segment                        0
# meal                                  0
# babies                                0
# ...

# %% [markdown]
# ## Visualizing the missing values

# %%
# Create a bar plot to visualize missing values
plt.figure(figsize=(10, 6))
sns.heatmap(df1.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()

# %% [markdown]
# **In above Heatmap missing values is clearly visible in some columns like country, agent, company**

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# **The given dataset is of Hotel Booking and we have to analyse and explore this dataset to discover important facrtors which affects the Hotel Booking. The above dataset has 119390 rows and 32 columns.The duplicate value count is 31994 rows and 32 columns. There are 4 columns in dataset which have missing valuse and those columns are company, agent, country and children.**

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df1.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
df1.describe(include='all')
# Out:
#              hotel   is_canceled     lead_time  arrival_date_year  \
# count        87396  87396.000000  87396.000000       87396.000000
# unique           2           NaN           NaN                NaN
# top     City Hotel           NaN           NaN                NaN
# freq         53428           NaN           NaN                NaN
# mean           NaN      0.274898     79.891368        2016.210296
# std            NaN      0.446466     86.052325           0.686102
# min            NaN      0.000000      0.000000        2015.000000
# 25%            NaN      0.000000     11.000000        2016.000000
# 50%            NaN      0.000000     49.000000        2016.000000
# 75%            NaN      1.000000    125.000000        2017.000000
# max            NaN      1.000000    737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count               87396              87396.000000
# unique                 12                       NaN
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# - `Hotel`: Type of hotel (City or Resort)
# - `is_cancelled`: If the booking was cancelled (1) or not (0)
# - `lead_time`: Number of days before the actual arrival of the guests
# - `arrival_date_year`: Year of arrival date
# - `arrival_date_month`: Month of arrival date
# - `arrival_date_week_number`: Week number of year for arrival date
# - `arrival_date_day_of_month`: Day of arrival date
# - `stays_in_weekend_nights`: Number of weekend nights (Saturday or Sunday) spent at the hotel by the guests.
# - `stays_in_week_nights`: Number of weeknights (Monday to Friday) spent at the hotel by the guests.
# - `adults`: Number of adults among the guests
# - `children`: Number of children
# - `babies`: Number of babies
# - `meal`: Type of meal booked
# - `country`: Country of the guests
# - `market_segment`: Designation of market segment
# - `distribution_channel`: Name of booking distribution channel
# - `is_repeated_guest`: If the booking was from a repeated guest (1) or not (0)
# - `previous_cancellations`: Number of previous bookings that were cancelled by the customer prior to the current booking
# - `previous_bookings_not_cancelled`: Number of previous bookings not cancelled by the customer prior to the current booking
# - `reserved_room_type`: Code for room type reserved
# - `assigned_room_type`: Code of room type assigned
# - `booking_changes`: Number of changes made to the booking
# - `deposit_type`: Type of deposit made by the guest
# - `agent`: ID of the travel agent who made the booking
# - `company`: ID of the company that made the booking
# - `days_in_waiting_list`: Number of days the booking was in the waiting list
# - `customer_type`: Type of customer, assuming one of four categories
# - `adr`: Average daily rate
# - `required_car_parking_spaces`: Number of car parking spaces required by the customer
# - `total_of_special_requests`: Number of special requests made by the customer
# - `reservation_status`: Reservation status (Canceled, check-out, or no-show)
# - `reservation_status_date`: Date at which the last reservation status was updated

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for column in df1.columns:
    unique_values = df1[column].unique()
    print(f"Unique values for {column}:\n{unique_values}\n")
# Out:
# Unique values for hotel:
# ['Resort Hotel' 'City Hotel']
#
# Unique values for is_canceled:
# [0 1]
#
# Unique values for lead_time:
# [342 737   7  13  14   0   9  85  75  23  35  68  18  37  12  72 127  78
#   48  60  77  99 118  95  96  69  45  40  15  36  43  70  16 107  47 113
#   90  50  93  76   3   1  10   5  17  51  71  63  62 101   2  81 368 364
#  324  79  21 109 102   4  98  92  26  73 115  86  52  29  30  33  32   8
#  100  44  80  97  64  39  34  27  82  94 110 111  84  66 104  28 258 112
#   65  67  55  88  54 292  83 105 280 394  24 103 366 249  22  91  11 108
#  106  31  87  41 304 117  59  53  58 116  42 321  38  56  49 317   6  57
#   19  25 315 123  46  89  61 312 299 130  74 298 119  20 286 136 129 124
#  327 131 460 140 114 139 122 137 126 120 128 135 150 143 151 132 125 157
#  147 138 156 164 346 159 160 161 333 381 149 154 297 163 314 155 323 340
#  356 142 328 144 336 248 302 175 344 382 146 170 166 338 167 310 148 165
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
#to fill the NaN value in the column, let's check which colomns has null value, we have already stored the same.
missing_values[:4]
# Out:
# company     82137
# agent       12193
# country       452
# children        4
# dtype: int64

# %%
#For company as it has numerical values,filling it with 0
df1['company'].fillna(0, inplace= True)

# %%
#For agent as it has numerical values,filling it with 0
df1['agent'].fillna(0, inplace= True)

# %%
#For country as it has string values,filling it with 'Other'
df1['country'].fillna('Other',inplace=True)

# %%
#For children as it has numerical value,filling it with 0
df1['children'].fillna(0,inplace=True)

# %%
#let's check whether database having any other null value
df1.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %% [markdown]
# ## **Adding New Columns**

# %%
# Adding total staying days in hotels
df1['total_stay'] = df1['stays_in_weekend_nights']+df1['stays_in_week_nights']

# Adding total people num as a column
df1['total_people'] = df1['adults']+df1['children']+df1['babies']

# %%
# view of df1 with added column
df1.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  company  \
# 0                        0                     0       2  ...      0.0
# ...

# %% [markdown]
# There are some rows with total number of adults, children or babies equal to zero this means there is no any booking were made. So we can remove such rows.###

# %%
# shape of columns which have no bookings
df1[df1['adults']+df1['babies']+df1['children'] == 0].shape
# Out:
# (166, 34)

# %%
# Rows are dropped here using drop function
df1.drop(df1[df1['adults']+df1['babies']+df1['children'] == 0].index, inplace = True)

# %%
df1.shape
# Out:
# (87230, 34)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
#   1.  We found that there were four columns containing null values so we had null values in columns-Company, agent, country and children
#
#   2. For Company, agent and children we filled the values with 0
#   3.   For Country we filled the values with object 'others'
#   4.   In the given dataframe, there were 31994 duplicate values. So those values were removed.
#   5.   we have created a three new columns for total stay, revenue and total_people.
#   6. In some columns of  'adults','children','babies' had value zero which means no booking has done here, so these rows were removed.

# %% [markdown]
# ## ***4. Data Visualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1
# 1. Which type of hotel is mostly prefered by the guests?

# %%
# Chart - 1 visualization code
hotel_value_counts = df1['hotel'].value_counts()
hotel_value_counts
# Out:
# City Hotel      53274
# Resort Hotel    33956
# Name: hotel, dtype: int64

# %%
plt.figure(figsize=(10, 7))
plt.pie(hotel_value_counts, labels=hotel_value_counts.index, autopct='%1.1f%%', colors=['lightblue', 'orange'])
plt.title ('Pie Chart for Most Preffered  Hotel',fontsize = '20')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# ### 1. Why did you pick the specific chart?

# %% [markdown]
#  Because Pie chart effectively displays the relative proportions or percentages of guests who prefer each type of hotel (City Hotel or Resort Hotel) out of the total number of guests. Here's why it's suitable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# I found that city hotel has more bookings which are 61.1% and Resort hotel has less bookings which are 38.9%

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, gained insights help creating a positive business impact.
#
# City hotel can find more services to attract more guests to increase more revenue.
#
# Resort hotel can find solution to attract guest and also find which facilities provided city hotel to attract the guest.

# %% [markdown]
# #### Chart - 2
# 2. Which agent made the most bookings?

# %%
# Chart - 2 visualization code
Most_bookings= df1.groupby(['agent'])['agent'].agg({'count'}).reset_index().rename(columns={'count': "Bookings" }).sort_values(by='Bookings',ascending=False)

# as agent 0 was NAN value and we replaced it with 0,so we are gonna drop it.
Most_bookings.drop(Most_bookings[Most_bookings['agent']==0].index,inplace=True)

# taking top 10 bookings made by agent
most_highest_bookings=Most_bookings[:10]

most_highest_bookings
# Out:
#      agent  Bookings
# 9      9.0     28721
# 174  240.0     13028
# 14    14.0      3342
# 7      7.0      3294
# 183  250.0      2779
# 175  241.0      1644
# 27    28.0      1493
# 8      8.0      1383
# 1      1.0      1228
# 6      6.0      1117

# %%
# Assuming you have a DataFrame named 'top_bookings_by_agent'
plt.figure(figsize=(14, 7))

# Define custom colors
colors = sns.color_palette("hls",10)

# Create the barplot with custom colors
sns.barplot(x=most_highest_bookings['agent'], y=most_highest_bookings['Bookings'], order=most_highest_bookings['agent'], palette=colors)

plt.title('Most bookings by the agent', fontsize=20)
plt.ylabel('Number of bookings', fontsize=15)
plt.xlabel('Agent number', fontsize=15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **I choose barplot here because it gives data visualization in pictorial form and due to this comparison of data is easy.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The insight found here is Agent no. 9 made most of the bookings.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  **Yes, Agent no.9, 240 has more bookings which makes positive impact.**
# **Agent no. 1 and 6 has less bookings which makes negative impact.Booking made by agent no 1 and 6 are about 4.27% of agent no 9 which has highest bookings.**

# %% [markdown]
# #### Chart - 3
# 3. What is the percentage of repeated guests?

# %%
# Chart - 3 visualization code
# 1 is for booking made by repeated guest and 0 is for booking not made by repeated guest
repeated_guests_count = df1['is_repeated_guest'].value_counts()
repeated_guests_count
# Out:
# 0    83866
# 1     3364
# Name: is_repeated_guest, dtype: int64

# %%
# Create a donut chart to visualize the percentage
plt.figure(figsize=(10, 7))
plt.pie(repeated_guests_count, labels=['Not Repeated (0)', 'Repeated (1)'], autopct='%1.1f%%', startangle=140, wedgeprops={'width': 0.4})
plt.title('Booking by Repeated Guests')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle with a hole (donut).
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **I use pie chart because pie chart gives simple and easy to understand picture that shows how many guests book particular hotel repeatedly.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The insight found from the chart is there are very few guests booking for the same hotel again.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Yes, the gained insights help creating a positive business impact like the hotels which do not booked repeatedly by guests can take feedbacks from the guests and try to impove there services.**

# %% [markdown]
# #### Chart - 4
# 4. What is the most preferred room type by the customers?

# %%
# Chart - 4 visualization
room_type = df1['assigned_room_type'].value_counts()
room_type
# Out:
# A    46283
# D    22419
# E     7190
# F     3627
# G     2495
# C     2160
# B     1811
# H      706
# I      353
# K      185
# L        1
# Name: assigned_room_type, dtype: int64

# %%
# Create a horizontal bar plot to visualize room preferences
# Define a custom color palette
colors = ['skyblue', 'lightcoral', 'lightgreen', 'lightsalmon', 'lightseagreen','red','orange','yellow','brown','pink','green']

# Create a horizontal bar plot with custom colors
plt.figure(figsize=(10, 7))
room_type.plot(kind='barh', color=colors)
plt.title('Most Preferred Room Type by Customers', fontsize=15)
plt.xlabel('Count', fontsize=12)
plt.ylabel('Room Type', fontsize=12)
plt.gca().invert_yaxis()  # Invert y-axis to display the highest count at the top
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **I have chosen a horizontal bar chart to visualize the most preferred roomtype because Bar chart display the count of each observation for each category and here we have to represent room type vs room type count.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The insight found from the chart is A type rooms are most prefered rooms and the count is 46283 and after that D type rooms are prefered by the guest and count is 22419.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **A type rooms are most preferred rooms. This make positive impact on business.
# H,I,K,L type rooms are less preferred this insight makes negative impact.
# This is because type A rooms have 46283 bookings anf type L room has only one booking. ****

# %% [markdown]
# #### Chart - 5
# 5. What type of food is mostly prefered by the guests?

# %%
# Chart - 5 visualization code
# Chart - 5 visualization code
preferred_food = df1['meal'].value_counts()
preferred_food
# Out:
# BB           67907
# SC            9391
# HB            9080
# Undefined      492
# FB             360
# Name: meal, dtype: int64

# %%
# Visualization of most preferred food using countplot
# Assuming 'df1' contains your DataFrame
plt.figure(figsize=(14, 7))

# Define a custom color palette
colors = sns.color_palette("hls")

# Create the countplot with custom colors
sns.countplot(x=df1['meal'], order=df1['meal'].value_counts().index, palette=colors)

plt.title("Most Preferred Food", fontsize=20)
plt.xlabel('Type of the food', fontsize=15)
plt.ylabel('Food type count', fontsize=15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **I have choose countplot to visualize most preferred food because countplot display the count of each observation for each category and here we have to represent food type vs food type count.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The insight found here is BB type food is most preferred anf FB type of food is less preferred.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **BB type of food is most preferred food this makes positive impact on business.
# Undefined and FB type of food is less preferred this insight makes negative impact on business.
# The BB type food is preferred by 67907 guests and FB type of food is preferred by only 360 guests.**

# %% [markdown]
# #### Chart - 6
# 6. "At what time of the year were most of the bookings registered?"

# %%
# Chart - 6 visualization code
bookings_by_months=df1.groupby(['arrival_date_month'])['hotel'].count().reset_index().rename(columns={'hotel':"Counts of booking"})
bookings_by_months
# Out:
#    arrival_date_month  Counts of booking
# 0               April               7900
# 1              August              11242
# 2            December               5112
# 3            February               6083
# 4             January               4685
# 5                July              10043
# 6                June               7756
# 7               March               7489
# 8                 May               8344
# 9            November               4973
# 10            October               6921
# 11          September               6682

# %%
bookings_by_months=df1.groupby(['arrival_date_month'])['hotel'].count().reset_index().rename(columns={'hotel':"Counts of booking"})
sequence_of_months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
bookings_by_months['arrival_date_month']=pd.Categorical(bookings_by_months['arrival_date_month'],categories=sequence_of_months,ordered=True)
bookings_by_months=bookings_by_months.sort_values('arrival_date_month')
bookings_by_months
# Out:
#    arrival_date_month  Counts of booking
# 4             January               4685
# 3            February               6083
# 7               March               7489
# 0               April               7900
# 8                 May               8344
# 6                June               7756
# 5                July              10043
# 1              August              11242
# 11          September               6682
# 10            October               6921
# 9            November               4973
# 2            December               5112

# %%
# barplot for visualization of month in which most booking happened.
plt.figure(figsize=(14,7))
sns.barplot(data=bookings_by_months, x="arrival_date_month", y="Counts of booking")
plt.title("Number of Bookings in Months", fontsize = 20)
plt.xlabel('Month', fontsize = 15)
plt.ylabel('Number of Bookings', fontsize = 15)
# Out:
# Text(0, 0.5, 'Number of Bookings')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **I choose barplot here because it gives data visualization in pictorial form. So comparison becomes easy.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The insight found from the chart is August month has maximum number of bookings.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **July and August months have most bookings this is positive impact on business
# November, December and January months have less bookings this is negative impact.
# July and August months have bookings above the average bookings and November, December and January months have bookings below the average bookings.**

# %% [markdown]
# #### Chart - 7
# 7. Which distribution channel is mostly used for hotel booking?

# %%
# Chart - 7 visualization code
# distribution channel value count
distribution_channel_counts = df1['distribution_channel'].value_counts()
distribution_channel_counts
# Out:
# TA/TO        69028
# Direct       12954
# Corporate     5062
# GDS            181
# Undefined        5
# Name: distribution_channel, dtype: int64

# %%
#shape of dataframe
d3 = df1.shape[0]
d3
# distribution channel count in df format
distribution_channel_df = df1['distribution_channel'].value_counts().reset_index().rename(columns={'index':"distribution_channel",'distribution_channel':'count'})
distribution_channel_df

# booking by distribution channel in percent
distribution_channel_df_percent = pd.DataFrame(round((distribution_channel_counts/d3)*100,2)).reset_index().rename(columns={'index':'distribution_channel','distribution_channel':'% booking'})
distribution_channel_df_percent
# Out:
#   distribution_channel  % booking
# 0                TA/TO      79.13
# 1               Direct      14.85
# 2            Corporate       5.80
# 3                  GDS       0.21
# 4            Undefined       0.01

# %%
#Visualization of mostly used distribution channels using barplot
plt.figure(figsize=(14,7))
sns.barplot(data=distribution_channel_df_percent, x="distribution_channel", y="% booking")
plt.title("Mostly used distribution Channels", fontsize = 20)
plt.xlabel('Distribution Channel', fontsize = 15)
plt.ylabel('Booking by distribution channel in percent', fontsize = 15)
# Out:
# Text(0, 0.5, 'Booking by distribution channel in percent')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Because barplot gives simple and easy to understand pictorial chart.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Mostly used distribution channel is TA/TO channel.The total count of booking is 69028 and booking in percent is 79.13.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Distribution channel TA/TO is mostly used channel this makes positive impact.
# Distribution channel GDS and undefined is less used channels this makes negative impact.
# Use of TA/TO is 79.13% and use of GDS is 0.21%.
# Other channels can provide those facilities which are provided by TA/TO channel.**

# %% [markdown]
# #### Chart - 8
# 8. which year had highest bookings?

# %%
# Chart - 8 visualization code
year_count = df1['arrival_date_year'].value_counts().sort_index()
year_count
# Out:
# 2015    13284
# 2016    42313
# 2017    31633
# Name: arrival_date_year, dtype: int64

# %%
# Visualization of year wise booking using countplot chart
plt.figure(figsize=(14,7))
sns.countplot(x=df1['arrival_date_year'],hue=df1['hotel'])
plt.title('Year wise Bookings', fontsize = 20)
plt.xlabel('Arrival_date_year', fontsize = 15)
plt.ylabel('Count of bookings', fontsize = 15)
# Out:
# Text(0, 0.5, 'Count of bookings')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Because clustered column chart is easy to understand multiple variable in visualisation**.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **2016 had highest bookings and 2015 had lowest bookings.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Year 2016 had highest bookings this makes positive impact.
# Year 2015 had lowest bookings this makes negative impact.
# In 2016 there were 42313 bookings and In 2015 there were 13284 bookings.**

# %% [markdown]
# #Bivariate and Multivariate analysis

# %% [markdown]
# #### Chart - 9
# 9. Which hotel type has the highest ADR?

# %%
# Chart - 9 visualization code
highest_adr = df1.groupby('hotel')['adr'].mean().reset_index()
highest_adr
# Out:
#           hotel         adr
# 0    City Hotel  111.271969
# 1  Resort Hotel   99.059517

# %%
# Visualization of highest adr using barplot
plt.figure(figsize=(10,5))
sns.barplot(x=highest_adr['hotel'],y=highest_adr['adr'])
plt.title('Average ADR for each Hotel type', fontsize=20)
plt.xlabel('Type of hotel',fontsize=15)
plt.ylabel('ADR', fontsize=15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **I choose bar plot because it gives simple pictorial diagram and it also easy to understand.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The insight found from the chart is City hotel has highest adr that means city hotel generate more revenue.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **City hotel has high adr this makes positive impact.
# Resort hotel has less adr as compare to city hotel this makes negative impact.
# City hotel has adr 111.27 means more revenue and resort hotel has 99.05 adr means less revenue than city hotel.
# Resort hotel should have increase there facilities which increase revenue.**

# %% [markdown]
# #### Chart - 10
# 10. which hotel has longer waiting time?

# %%
# Chart - 10 visualization code
Waiting_time = df1.groupby('hotel')['days_in_waiting_list'].mean().reset_index()
Waiting_time
# Out:
#           hotel  days_in_waiting_list
# 0    City Hotel              1.020066
# 1  Resort Hotel              0.316763

# %%
# Assuming you have a DataFrame named 'Waiting_time'
plt.figure(figsize=(14, 7))

# Define a custom color palette
colors = sns.color_palette("husl")

# Create the barplot with custom colors
sns.barplot(x=Waiting_time['hotel'], y=Waiting_time['days_in_waiting_list'], palette=colors)

plt.title('Waiting time for each hotel type', fontsize=20)
plt.xlabel('Type of hotel', fontsize=15)
plt.ylabel('Waiting time', fontsize=15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **I choose barplot becuase it gives easy to understand pictorial diagram for the visualization of which hotel has longer waiting time.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **City hotel has longer waiting time.Therefore city hotel is much busier than Resort hotel.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **City hotel has longer waiting time this makes positive impact on business.
# Resort hotel has less waiting time this makes negative impact on business.
# The mean of days in waiting list for city hotel is about 1.02 and for resort hotel is about 0.31.
# Resort hotel need to increase their facilities so that their bookings increases.**

# %% [markdown]
# #### Chart - 11
# 11. Which distribution channel contributed more to adr in order to increase the income?

# %%
# Chart - 11 visualization code
distribution_channel = df1.groupby(['distribution_channel','hotel'])['adr'].mean().reset_index()
distribution_channel
# Out:
#   distribution_channel         hotel         adr
# 0            Corporate    City Hotel   83.777368
# 1            Corporate  Resort Hotel   53.036835
# 2               Direct    City Hotel  112.606688
# 3               Direct  Resort Hotel  106.566215
# 4                  GDS    City Hotel  120.317845
# 5                TA/TO    City Hotel  112.663552
# 6                TA/TO  Resort Hotel  101.578317
# 7            Undefined    City Hotel   29.625000
# 8            Undefined  Resort Hotel  112.700000

# %%
# Visualization of contribution of distribution channel in adr using barplot
plt.figure(figsize=(14,7))
sns.barplot(x='distribution_channel',y='adr', data=distribution_channel,hue='hotel')
plt.title('ADR across Distribution channel', fontsize=20)
plt.xlabel('Distribution channel',fontsize=15)
plt.ylabel('ADR', fontsize=15)
# Out:
# Text(0, 0.5, 'ADR')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **I choose here clustered column chart to visualise ADR across distribution channel beacuse it give easy to undertand visualization to large data.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The insight found from the above chart is that GDS channel contributed most in ADR in city hotel and Direct and TA/TO has nearly equal contribution in adr in both hotel types.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **GDS distribution channel contributed more to adr for city hotel and Undefined distribution channel contributed more to adr for resort hotel this makes positive impact.
# GDS distribution channel has no any contribution to adr for resort hotel and undefined distribution channel contributed less to adr for city hotel this makes neative impact.
# GDS distribution channel must have increase bookings for resort hotels therefore there contribtuion to adr will increase and income will increase and undefined distribution channel must have increase bookings for city hotels therefore there contribution to adr will increase and income will increase.**

# %% [markdown]
# #### Chart - 12
# 12. What is optimal stay length in both types of hotel

# %%
# Chart - 12 visualization code
stay_length = df1.groupby(['total_stay','hotel']).agg('count').reset_index()
stay_length = stay_length.iloc[:, :3]
stay_length = stay_length.rename(columns={'is_canceled':'Number of stays'})
stay_length
# Out:
#     total_stay         hotel  Number of stays
# 0            0    City Hotel              231
# 1            0  Resort Hotel              360
# 2            1    City Hotel            10270
# 3            1  Resort Hotel             6899
# 4            2    City Hotel            10813
# ..         ...           ...              ...
# 68          46  Resort Hotel                1
# 69          48    City Hotel                1
# 70          56  Resort Hotel                2
# 71          60  Resort Hotel                1
# 72          69  Resort Hotel                1
#
# [73 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'stay_length' with columns 'total_stay', 'hotel', and 'Number of stays'
plt.figure(figsize=(12, 6))

# Create a point plot to show optimal stay length in both hotel types
sns.pointplot(x='total_stay', y='Number of stays', hue='hotel', data=stay_length)

plt.title('Optimal Stay Length in Both Hotel Types', fontsize=20)
plt.xlabel('Total Stay Days', fontsize=15)
plt.ylabel('Number of Stays', fontsize=15)
plt.legend(title='Hotel Type', loc='upper right')
plt.grid(True, linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **I choose point plot chart Because it gives simple visualization over the period.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Optimal stay length in both hotel type is less than 7 days.**

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
guest_country_wise = pd.DataFrame(df1[['country', 'total_people']])
guest_country_wise_df = guest_country_wise.groupby(['country'])['total_people'].sum()
guest_country_wise_df.sort_values(ascending = False, inplace = True)
Top_10_country_by_guest = guest_country_wise_df.head(10)

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=Top_10_country_by_guest.index, y=Top_10_country_by_guest)
plt.title('Top 10 Countries by Guest')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **To determine which country the majority of the guests are coming from.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **As we can see, that maximum guest is coming from Portugal**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **We can do more advertising & can provide attractive offers to Portugal guests to enhance the customer**

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
plt.figure(figsize=(20,10))
sns.heatmap(df1.corr(),annot=True)
plt.title('Correlation of the columns')
plt.show()
# Out:
# <ipython-input-56-f0459d2e1549>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df1.corr(),annot=True)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **I choose heatmap here becuase heatmap display a more eneralized view of neumeric values and also utilize color coded systems.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **arrival_date_year and arrival_date_week_number columns has negative correlation which is -0.51.
# stays_in_week_nights and total_stay has positive correlation which is 0.95.**

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
numerical_columns = [
    'lead_time','previous_cancellations', 'previous_bookings_not_canceled', 'total_people','booking_changes', 'days_in_waiting_list', 'adr',
    'total_of_special_requests'
]

# Create a pair plot
sns.set(style="ticks")
sns.pairplot(df1[numerical_columns])

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **To visualize relationships between pairs of variables in a dataset**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Here we can see that the relationship of one column with another one**

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# * To increase hotel business some factors are important like high revenue,
# generation, customers satisfaction, facilities provided by hotel etc.
# * I am able to achieve the same things by showing to client which hotel is most preferred , percentage of repeated guests, mostly preferred food by guests, then which hotel has highest adr etc.
# * Most preferred room type is achieved by countplot so the client can be well prepare in advance and this insight help client for further enhancement of their hospatility.
# * I am able to show which food type is mostly preferred so client can offer the mostly preferred food to the guests.
# * Most preferred month are shown by barplot so client can be well prepared in advanced so that minimum grivances would be faced by client.
# * Using barplot I am able to show which hotel type has high adr so client can analyse which hotel has high income.
# * I am able to show which hotel is busiest hotel sp client can do relatable changes in facilities in less busy hotel type.
# * I am able to show the relationship between repeated guests and previous bookings not cancelled so client can preferred repeated guests.
# * Using barplot relationship between adr and total number of people is shown so client can preferred maximum number of people.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# * 1) City hotel is mostly preferred hotel by guests.
# * 2) Agent no. 9 made the most bookings.
# * 3) Percentage of repeated guest is less which is 3.9%.
# * 4) Room type A is mostly preferred room type.
# * 5) Mostly preferred food type is BBtype food.
# * 6) August month has most bookings and after august july has most bookings.
# * 7) TA/TO distribution channel is mostly used and percentage is 79.13%.
# * 8) City hotel has highest ADR. Highest ADR means more revenue.
# * 9) 2016 year had highest bookings and bookings were 42313.
# * 10) City hotel has higher waiting time means city hotel is busier hotel.
# * 11) GDS distribution channel contributed most inADR in city hotel but no contribution in resoert hotel.
# * 12) Optimal stay length in both hotel type is less than 7 days.
# * 13) Repeated guests do not cancel their bookings but not repeated guests cancel.
# * 14) If number of people is more then ADR is also increases means revenue increases.
# * 15) arrival_date_year and arrival_date_week_number columns has negative correlation which is -0.51.
# * 16) stays_in_weel_nights and total_stays has positive correlation which is 0.95.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
